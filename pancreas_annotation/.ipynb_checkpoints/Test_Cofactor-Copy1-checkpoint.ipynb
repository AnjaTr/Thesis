# %%
import diptest
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Path to pancreas files
Run64_ROI6_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI6_DATA/Run64_Pankreas_ROI6_METADATA.csv'
Run64_ROI6_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI6_DATA/Run64_Pankreas_ROI6_EXPRESSION_cor.csv'
Run64_ROI8_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI8_DATA/Run64_Pankreas_ROI8_METADATA.csv'
Run64_ROI8_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI8_DATA/Run64_Pankreas_ROI8_EXPRESSION_cor.csv'
Run64_ROI10_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI10_DATA/Run64_Pankreas_ROI10_METADATA.csv'
Run64_ROI10_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI10_DATA/Run64_Pankreas_ROI10_EXPRESSION_cor.csv'
Run64_ROI12_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI12_DATA/Run64_Pankreas_ROI12_METADATA.csv'
Run64_ROI12_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI12_DATA/Run64_Pankreas_ROI12_EXPRESSION_cor.csv'
Run64_ROI14_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI14_DATA/Run64_Pankreas_ROI14_METADATA.csv'
Run64_ROI14_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI14_DATA/Run64_Pankreas_ROI14_EXPRESSION_cor.csv'
Run64_ROI15_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI15_DATA/Run64_Pankreas_ROI15_METADATA.csv'
Run64_ROI15_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI15_DATA/Run64_Pankreas_ROI15_EXPRESSION_cor.csv'
Run64_ROI19_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI19_DATA/Run64_Pankreas_ROI19_METADATA.csv'
Run64_ROI19_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI19_DATA/Run64_Pankreas_ROI19_EXPRESSION_cor.csv'
Run64_ROI22_meta = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI22_DATA/Run64_Pankreas_ROI22_METADATA.csv'
Run64_ROI22_expr = '~/Documents/Masterarbeit/data/Run64_Pankreas_ROI22_DATA/Run64_Pankreas_ROI22_EXPRESSION_cor.csv'

# %%
# select relevant marker
selced_marker = [
'CD45',  
'CD45RO',   
'CD3',
# CD2,
'CD4',
'CD8',    
'CD25-1',     
'FoxP3',
'CD152 CTLA4',   
#PD-L1
'CD19',     
'CD20 Cytoplasmic',
'CD38',     
'CD138', 
'CD69',    
'CD56',    
'CD314 NKG2D',     
'CD61',
'CD68', 
'CD206',     
'CD163',# IN ROI19 on tumor       
'CD11c', 
'CD123',
'CD15',    
'CD33',  
'CD117',   
'HLA-DR',
'Ki-67',     
'HNF-4-alpha',  
'Cytokeratin',    
'CD99',
'CD31',    
'CD105',    
'Podoplanin',
'SM Actin',
'Myosin SM',
'CollagenIII',
'CollagenIV',
'Fibronectin',
'Galectin9',    
]

# %%
raw_data = pd.read_csv(Run64_ROI6_expr, index_col="ID", sep='\t') 
raw_data = raw_data[selced_marker]

# %%
for i in raw_data:
    binom_res = []
    for j in range(1, 3):
        x = raw_data[i].apply(lambda x: np.arcsinh(x))/j 
        x = x.to_numpy()
        binom = diptest.dipstat(x)
        binom_res.append(binom)
        j += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_71093/1994209914.py in <module>
#       2     binom_res = []
#       3     for j in range(1, 200):
# ----> 4         x = raw_data[i].apply(lambda x: np.arcsinh(x))/j
#       5         x = x.to_numpy()
#       6         binom = diptest.dipstat(x)
#
# ~/.pyenv/versions/3.7.12/envs/thesis/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/.pyenv/versions/3.7.12/envs/thesis/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/.pyenv/versions/3.7.12/envs/thesis/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# ~/.pyenv/versions/3.7.12/envs/thesis/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_71093/1994209914.py in <lambda>(x)
#       2     binom_res = []
#       3     for j in range(1, 200):
# ----> 4         x = raw_data[i].apply(lambda x: np.arcsinh(x))/j
#       5         x = x.to_numpy()
#       6         binom = diptest.dipstat(x)
#
# KeyboardInterrupt:

# %%
# Arcsinh transformation
transformed_data = raw_data.apply(lambda x: np.arcsinh(x))

# %%
binom_res = []
for i in range(1, 200):
    x = test_marker.apply(lambda x: np.arcsinh(x))/i 
    x = x.to_numpy()
    binom = diptest.dipstat(x)
    binom_res.append(binom)
    i += 1

# %%
max(binom_res)
# Out:
# 0.0019907341818860037

# %%
highest_prob = np.argmax(binom_res)
highest_prob
# Out:
# 192

# %%
list_highest_prob = test_marker.apply(lambda x: np.arcsinh(x))/ highest_prob
list_highest_prob = list_highest_prob.to_frame()

# %% [markdown]
# ### Results of Dip test
# The dip statistic tells you the probability of the empirical distribution function being bimodal. By having a large value dip, the empirical data is more probable to have multiple modes

# %%
# y-axis in a density plot is the probability density function for the kernel density estimation.
ax = sns.displot(transformed_data, x='CD45', kind="kde", fill=True)
ax.set(xlabel='Probability density', ylabel='Count', title='CD45')

# %%
ax = sns.displot(list_highest_prob, x='CD45', kind="kde", fill=True)
ax.set(xlabel='Probability density', ylabel='Count', title='CD45')

# %%
ax = sns.histplot(data=transformed_data, x="CD45")
ax.set(xlabel='Floursecence value', ylabel='Count', title='CD45')
# Out:
# [Text(0.5, 0, 'Floursecence value'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'CD45')]

# %%
ax = sns.histplot(data=list_highest_prob, x="CD45")
ax.set(xlabel='Floursecence value', ylabel='Count', title='CD45')
# Out:
# [Text(0.5, 0, 'Floursecence value'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'CD45')]
